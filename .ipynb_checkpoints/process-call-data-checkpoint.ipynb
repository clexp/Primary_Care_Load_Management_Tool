# %% [markdown]
# # This is the opening exploration of Data from the phone system
#
# This data was exported piecemeal from excel and imported to pandas and unified as a dataset.

# %%
import pandas as pd
import glob
import os

# Define the directory path relative to the script location
directory =  "Attachments_call_data"

# Get all CSV files in the directory that match the pattern
csv_files = glob.glob(os.path.join(directory, "csv-queue-report*.csv"))

# List to store individual dataframes
dfs = []

# Read each CSV file
for file in csv_files:
    # Read CSV file
    df = pd.read_csv(file)
    
    # Remove the "Total" row
    df = df[df['Time'] != 'Total']
    
    # Convert Time column to datetime
    df['Time'] = pd.to_datetime(df['Time'])
    
    # Add to list of dataframes
    dfs.append(df)

# Combine all dataframes
combined_df = pd.concat(dfs, ignore_index=True)

# Sort by time
combined_df = combined_df.sort_values('Time')

# Remove duplicates if any
combined_df = combined_df.drop_duplicates(subset=['Time'])

# %% [markdown]
# # Simple Exploration
#
# What do we notice first about the data?

# %%
combined_df.head()
# Out:
#                  Time  Total Calls  Total Calls [Min. Call Length]  \
# 0 2024-12-02 08:00:00          272                           272.0
# 1 2024-12-02 08:30:00          248                           248.0
# 2 2024-12-02 09:00:00          107                           107.0
# 3 2024-12-02 09:30:00           43                            43.0
# 4 2024-12-02 10:00:00           75                            75.0
#
#    Connected Calls  Calls Not Connected  \
# 0               78                  194
# 1               33                  215
# 2               22                   85
# 3               13                   30
# 4               12                   63
#
#    Calls Not Connected (Length Limit Reached)  \
# 0                                         193
# 1                                         212
# 2                                          80
# 3                                          26
# 4                                          62
#
#    Calls Not Connected (Contact Hung Up)  \
# 0                                      1
# 1                                      3
# 2                                      5
# 3                                      4
# 4                                      1
#
#    Calls Not Connected (Caller Hangup Within 5 Seconds)  \
# 0                                                  0
# 1                                                  0
# 2                                                  1
# 3                                                  0
# 4                                                  0
#
#    Calls Not Connected (Caller Hangup Within 10 Seconds)  \
# 0                                                  0
# 1                                                  0
# 2                                                  1
# 3                                                  2
# 4                                                  1
#
#    Calls Not Connected (Caller Hangup Within 20 Seconds)  Availability (%)  \
# 0                                                  0                 28.68
# 1                                                  0                 13.31
# 2                                                  2                 20.56
# 3                                                  2                 30.23
# 4                                                  1                 16.00
#
#    TOTAL CALLS INCLUDING HANGUPS (M)  Avg Call Length (s)  \
# 0                              856.0                189.0
# 1                              895.2                217.0
# 2                              870.9                488.0
# 3                              657.3                917.0
# 4                              320.4                256.0
#
#    Longest Wait Time (s)  Avg Wait Time (s)  Avg Answer Time (s)  \
# 0                   1066             161.16               554.21
# 1                   2193             193.33              1318.63
# 2                   3818             442.13              2095.96
# 3                   3926             865.17              2806.11
# 4                   2477             236.30              1476.34
#
#    Avg Wrap Up Time (s)  Max. Queue Length  Avg Talk Time (s)
# 0                 17.39                 20              96.31
# 1                 18.90                 20             174.26
# 2                 20.15                 20             224.63
# 3                 20.00                 20             171.84
# 4                 23.07                 20             125.10

# %%
combined_df.head(2)
# Out:
#                  Time  Total Calls  Total Calls [Min. Call Length]  \
# 0 2024-12-02 08:00:00          272                           272.0
# 1 2024-12-02 08:30:00          248                           248.0
#
#    Connected Calls  Calls Not Connected  \
# 0               78                  194
# 1               33                  215
#
#    Calls Not Connected (Length Limit Reached)  \
# 0                                         193
# 1                                         212
#
#    Calls Not Connected (Contact Hung Up)  \
# 0                                      1
# 1                                      3
#
#    Calls Not Connected (Caller Hangup Within 5 Seconds)  \
# 0                                                  0
# 1                                                  0
#
#    Calls Not Connected (Caller Hangup Within 10 Seconds)  \
# 0                                                  0
# 1                                                  0
#
#    Calls Not Connected (Caller Hangup Within 20 Seconds)  Availability (%)  \
# 0                                                  0                 28.68
# 1                                                  0                 13.31
#
#    TOTAL CALLS INCLUDING HANGUPS (M)  Avg Call Length (s)  \
# 0                              856.0                189.0
# 1                              895.2                217.0
#
#    Longest Wait Time (s)  Avg Wait Time (s)  Avg Answer Time (s)  \
# 0                   1066             161.16               554.21
# 1                   2193             193.33              1318.63
#
#    Avg Wrap Up Time (s)  Max. Queue Length  Avg Talk Time (s)
# 0                 17.39                 20              96.31
# 1                 18.90                 20             174.26

# %% [markdown]
# ### What are the data structures?

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 567 entries, 0 to 125
# Data columns (total 19 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Time                                                   567 non-null    datetime64[ns]
#  1   Total Calls                                            567 non-null    int64
#  2   Total Calls [Min. Call Length]                         546 non-null    float64
#  3   Connected Calls                                        567 non-null    int64
#  4   Calls Not Connected                                    567 non-null    int64
#  5   Calls Not Connected (Length Limit Reached)             567 non-null    int64
#  6   Calls Not Connected (Contact Hung Up)                  567 non-null    int64
#  7   Calls Not Connected (Caller Hangup Within 5 Seconds)   567 non-null    int64
#  8   Calls Not Connected (Caller Hangup Within 10 Seconds)  567 non-null    int64
#  9   Calls Not Connected (Caller Hangup Within 20 Seconds)  567 non-null    int64
#  10  Availability (%)                                       567 non-null    float64
#  11  TOTAL CALLS INCLUDING HANGUPS (M)                      567 non-null    float64
#  12  Avg Call Length (s)                                    567 non-null    float64
#  13  Longest Wait Time (s)                                  567 non-null    int64
#  14  Avg Wait Time (s)                                      567 non-null    float64
#  15  Avg Answer Time (s)                                    567 non-null    float64
#  16  Avg Wrap Up Time (s)                                   567 non-null    float64
#  17  Max. Queue Length                                      567 non-null    int64
#  18  Avg Talk Time (s)                                      546 non-null    float64
# dtypes: datetime64[ns](1), float64(8), int64(10)
# memory usage: 88.6 KB
